# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
products = pd.read_table('data/products.tsv')
products.set_index('product_id', verify_integrity=True, inplace=True)
products.drop(['product_url'], axis=1, inplace=True)
products.head()
# Out:
#                                                  product_name material  \
# product_id
# 103205      Hwipure, Disposable KF94 ( N95 / KN95/ FFP2 ) ...    other
# 101774      HIGUARD, Disposable KF94 ( N95 / KN95/ FFP2 ) ...    other
# 101955      SunJoy, KN95, Professional Protective Disposab...    other
# 103838             Lozperi, Copper Mask, Adult, Black, 1 Mask   copper
# 102734            Zidian, Disposable Protective Mask, 50 Pack    other
#
#             n_masks    brand  product_price
# product_id
# 103205            1  Hwipure           2.95
# 101774            1  HIGUARD           2.95
# 101955           10   Sunjoy           8.86
# 103838            1  Lozperi           6.85
# 102734           50   Zidian          15.35

# %%
reviews = pd.read_table('data/reviews.tsv')
reviews.head()
# Out:
#    abuseCount customerNickname  helpfulNo  helpfulYes  \
# 0           0   iHerb Customer          0           6
# 1           0   iHerb Customer          0           0
# 2           0   iHerb Customer          0           0
# 3           0     InnaIgorevna          0           0
# 4           0   iHerb Customer          0           0
#
#                                      id  imagesCount languageCode  \
# 0  05c2b17e-c28d-4792-930d-27e787d8d4ad            1        en-US
# 1  80e44af8-2edf-4b81-a80a-7e7888d03cc0            0        ru-RU
# 2  9a76e047-21e4-4da3-8b50-9d2396519b6b            0        en-US
# 3  2890ac54-8707-418e-be3e-8d46231e3672            0        ru-RU
# 4  9db33354-0457-4efa-bc9c-b5f7ee0eff31            0        ru-RU
#
#                  postedDate  productId  profileInfo.ugcSummary.answerCount  \
# 0  2021-01-27T09:04:10.569Z     103839                                 0.0
# 1  2021-02-07T00:56:39.055Z     103839                                 0.0
# ...

# %%
reviews['productId'].isin(products.index).all()
# Out:
# True

# %%
reviews.shape
# Out:
# (3849, 19)

# %%
R = reviews.join(products, on='productId')

# %%
R.head()
# Out:
#    abuseCount customerNickname  helpfulNo  helpfulYes  \
# 0           0   iHerb Customer          0           6
# 1           0   iHerb Customer          0           0
# 2           0   iHerb Customer          0           0
# 3           0     InnaIgorevna          0           0
# 4           0   iHerb Customer          0           0
#
#                                      id  imagesCount languageCode  \
# 0  05c2b17e-c28d-4792-930d-27e787d8d4ad            1        en-US
# 1  80e44af8-2edf-4b81-a80a-7e7888d03cc0            0        ru-RU
# 2  9a76e047-21e4-4da3-8b50-9d2396519b6b            0        en-US
# 3  2890ac54-8707-418e-be3e-8d46231e3672            0        ru-RU
# 4  9db33354-0457-4efa-bc9c-b5f7ee0eff31            0        ru-RU
#
#                  postedDate  productId  profileInfo.ugcSummary.answerCount  \
# 0  2021-01-27T09:04:10.569Z     103839                                 0.0
# 1  2021-02-07T00:56:39.055Z     103839                                 0.0
# ...

# %%
products.loc[103839]
# Out:
# product_name     Lozperi, Copper Mask, Adult, Dot, 1 Count
# material                                            copper
# n_masks                                                  1
# brand                                              Lozperi
# product_price                                         6.85
# Name: 103839, dtype: object

# %%
R.to_csv('data/facemasks.tsv', sep='\t', index=False)
