# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_table('data/facemasks.tsv').drop_duplicates()
df.set_index('id', verify_integrity=True, inplace=True)
df.head()
# Out:
#                                       abuseCount customerNickname  helpfulNo  \
# id
# 05c2b17e-c28d-4792-930d-27e787d8d4ad           0   iHerb Customer          0
# 80e44af8-2edf-4b81-a80a-7e7888d03cc0           0   iHerb Customer          0
# 9a76e047-21e4-4da3-8b50-9d2396519b6b           0   iHerb Customer          0
# 2890ac54-8707-418e-be3e-8d46231e3672           0     InnaIgorevna          0
# 9db33354-0457-4efa-bc9c-b5f7ee0eff31           0   iHerb Customer          0
#
#                                       helpfulYes  imagesCount languageCode  \
# id
# 05c2b17e-c28d-4792-930d-27e787d8d4ad           6            1        en-US
# 80e44af8-2edf-4b81-a80a-7e7888d03cc0           0            0        ru-RU
# 9a76e047-21e4-4da3-8b50-9d2396519b6b           0            0        en-US
# 2890ac54-8707-418e-be3e-8d46231e3672           0            0        ru-RU
# 9db33354-0457-4efa-bc9c-b5f7ee0eff31           0            0        ru-RU
#
# ...

# %%
r = df.groupby('brand')['ratingValue'].mean()

# %%
s = df.groupby('brand')['product_price'].sum()

# %%
x = pd.DataFrame.from_dict({'rating': r, 'sales': s})

# %%
plt.style.use('ggplot')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x='rating', y='sales', data=x)
ax.set_xlabel('Average Product Rating', fontweight='heavy')
ax.set_ylabel('Total Sales (in AU$)', fontweight='heavy')

ax.text(44, 1000, 'Dr Puri')
ax.text(46.071429, 1239.84, 'Hwipure')
ax.text(43.348214, 15877.12, 'Kitsch')
ax.text(45.325670, 17516.20, 'Kosette')
ax.text(46.179775, 609.65, 'Lozperi')
ax.text(46.498516, 5172.95, 'Zidian')
ax.text(37.333333, 4205.20, 'Luseta Beauty')
# Out:
# Text(37.333333, 4205.2, 'Luseta Beauty')

# %%
x
# Out:
#                    rating     sales
# brand
# Dr Puri         44.250000   1889.60
# HIGUARD         45.833333    495.60
# Hwipure         46.071429   1239.84
# Kitsch          43.348214  15877.12
# Kosette         45.325670  17516.20
# La Hauteur      45.511111   1262.25
# Landsberg       40.465116   1571.22
# Lozperi         46.179775    609.65
# Luseta Beauty   37.333333   4205.20
# Now Foods       40.588235    200.60
# One Fine Day    41.200000    112.25
# Puritas         45.869565    304.06
# Sunjoy          44.285714   5829.88
# Tony Moly       44.275862   3852.65
# YJ Corporation  45.588235    267.24
# Zidian          46.498516   5172.95

# %%
x.sort_values('rating', ascending=False)
# Out:
#                    rating     sales
# brand
# Zidian          46.498516   5172.95
# Lozperi         46.179775    609.65
# Hwipure         46.071429   1239.84
# Puritas         45.869565    304.06
# HIGUARD         45.833333    495.60
# YJ Corporation  45.588235    267.24
# La Hauteur      45.511111   1262.25
# Kosette         45.325670  17516.20
# Sunjoy          44.285714   5829.88
# Tony Moly       44.275862   3852.65
# Dr Puri         44.250000   1889.60
# Kitsch          43.348214  15877.12
# One Fine Day    41.200000    112.25
# Now Foods       40.588235    200.60
# Landsberg       40.465116   1571.22
# Luseta Beauty   37.333333   4205.20
